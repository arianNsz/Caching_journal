# %%
# %load_ext tensorboard

# %%
cd Desktop/Research/Code
# Out:
# [WinError 3] The system cannot find the path specified: 'Desktop/Research/Code'
# C:\Users\arian92\Desktop\Research\Code

# %%
pwd
# Out:
# 'C:\\Users\\arian92\\Desktop\\Research\\Code'

# %%
# %tensorboard --logdir ./logs/
# Out:
# Reusing TensorBoard on port 6006 (pid 12812), started 0:14:43 ago. (Use '!kill 12812' to kill it.)
# invalid info file: 'C:\\Users\\arian92\\AppData\\Local\\Temp\\.tensorboard-info\\pid-6612.info'
# Traceback (most recent call last):
#   File "C:\Users\arian92\Anaconda3\envs\tf1.14\lib\site-packages\tensorboard\manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "C:\Users\arian92\Anaconda3\envs\tf1.14\lib\site-packages\tensorboard\manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXI9Li9EZXNrdG9wL1Jlc2VhcmNoL0NvZGUvYTJjX2ZpbmFsX3RlbnNvcmJvYXJkLyJdLCJjb25maWd1cmVfa3dhcmdzIjp7fSwid29ya2luZ19kaXJlY3RvcnkiOiJDOlxcVXNlcnMifQ==', 'db': '', 'logdir': './Desktop/Research/Code/a2c_final_tensorboard/', 'path_prefix': '', 'pid': 6612, 'port': 6006, 'start_time': 1593747060, 'version': '2.2.1'}
# ...
